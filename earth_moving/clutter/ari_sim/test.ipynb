# %%
# !python3 ../../../earth_moving/runners/ari_pybullet_runner.py
# Out:
# pybullet build time: May 20 2024 15:34:46
# Traceback (most recent call last):
#   File "/home/fedeoli/Documents/Work/earth_moving/earth_moving/clutter/ari_sim/../../../earth_moving/runners/ari_pybullet_runner.py", line 31, in <module>
#     ari_scenario(pybullet_running_config)
#   File "/home/fedeoli/Documents/Work/earth_moving/earth_moving/scenarios/ari_scenario.py", line 8, in ari_scenario
#     Backend = Basebackend.initiate_backend(config)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: BaseBackend.initiate_backend() takes 1 positional argument but 2 were given
