# %%
from earth_moving.scenarios.fedeoli_beavers_scenario_GIF import fedeoli_beavers_scenario_GIF

beavers_running_config = {
    'backend_type': 'beavers_visualizer',    
    'environment':
        {
          'name': 'beavers_environment',
          'width': 200,
          'height': 100,        
          'number_vegetation_clusters_init': 20,
          'number_vegetation_clusters_max': 20,
          'vegetation_cluster_sigma': 6,
          'vegetation_cluster_radius_range': [8, 8],          
          'vegetation_quality_range' : [1, 10],     
          'vegetation_quality_init_range': [6, 7],    
          'vegetation_growth_frequency': 24*30,  # in hours
          'streams_number': 1,
          'streams_width': 4,          
          'print': False,      
        },   
    'robot':
        {
            'name': 'beavers_robot',
            'range_x': [0, 200],                    # [0, width]  (check environment width)
            'range_y': [0, 100],                    # [0, height] (check environment height)
            'position': 'home',                  # 'random' or [x, y] according to the ranges below
            'home_base_position': [100, 50],        # [x, y] according to the ranges below            
            'initial_load': 0,                      # 'random' or [0, maximum_load]
            'maximum_load': 500,
            'initial_energy': 100,                  # [0, 100] - hard coded                        
            'motion_consumption': 0,                # positive, the minus will be handled in the class __init__
            'load_consumption': 0,                  # positive, the minus will be handled in the class __init__
            'harvest_consumption': 0,               # positive, the minus will be handled in the class __init__
            'harvest_threshold': [3, 8],                 # [min_quality + 1, max_quality] (check environment vegetation_quality_range)
            'vegetation_removal': 1,
            'sleep_recovery': 1,
            'measurement_mode': 'D40',
            'exploration_mode': 'gradient_D00',     # 'random' and/or 'D4' or 'gradient_D4' or 'gradient_D8'            
            'exploration_map': 'vegetation_visits',        # 'vegetation_visits' or 'vegetation'
            'exploration_eta': 0.9,
            'exploration_N_recovery': 40,
            'print': False,
            'controller': {                
                'name':'P_repulsive',
                'Kp': 1,                 
                'map_repulsive': 'vegetation_visits',
                'neighbourhood_size': 8,
                'visits_reset': 0.99,
                'beta_repulsive': 0.95,                
                'vegetation_barrier': [0.1, 1],
                'river_barrier': -0.1,
                'max':1.0,
                'accuracy':1e-2,
                'dimension':2,
            },
            'dynamics': {
                'name':'integrator',
                'mass':1.0,         #? Do we need to implement beavers with different masses? Does it depend on the load?
                'friction':1.0      #? Do we need to implement beavers with different frictions? Does it depend on the environment?
            }
        },
    'simulation':
        {
            'seed': 0,
            'timedelta': 1.0,
            'schedule_policy': 'sequential',                   # 'random' or 'sequential'
            'gui': False,
            'number_of_agents': 1,
            'print': False,
            'output_dir': 'earth_moving/outputs/fig/050525',
            'number_of_steps': 365*3    ,
            'downsampling': 50,
        },    
    }

# %%
from IPython.display import clear_output
fedeoli_beavers_scenario_GIF(beavers_running_config)
clear_output(wait=True)
