# %%
from earth_moving.scenarios.fedeoli_beavers_scenario_GIF import fedeoli_beavers_scenario_GIF

beavers_running_config = {
    'backend_type': 'beavers_visualizer',    
    'environment':
        {
          'name': 'beavers_environment',
          'map_mode': 'csv',
          'elevation_file_path': 'earth_moving/clutter/csv_analysis/output/elevation.npy',
        #   'elevation_file_path': 'outputs/maps/environment_map_explore_grass.npy',
          'latitude_file_path': 'earth_moving/clutter/csv_analysis/output/X_coordinates.npy',
          'longitude_file_path': 'earth_moving/clutter/csv_analysis/output/Y_coordinates.npy',
          'vegetation_quality_range': [0, 10],
          'grass_growth_rate': 1e-3,
          'grass_growth_interval': [0, 3],
          'visits_reset': 0.999,
          'flow_info': {
              'direction': [0, 0],
              'strength': 0.0,
              'streams_width': 10,  # depth
              'river_growth_velocity': 5e0,
          },
          'print': False,
        },
    'robot':
        {
            'name': 'beavers_robot',
            'position': 'random_home',
            'home_base_position': [[100,80],[130,140]], #,[65,130]
            'range_x': [-3, 3],
            'range_y': [-3, 3],            
            'initial_load': 0,                   
            'maximum_load': 20,
            'initial_energy': 100,               
            'motion_consumption': 0,             
            'load_consumption': 0,               
            'harvest_consumption': 0,            
            'harvest_threshold': [[0,2]],#, 
            'vegetation_removal': 0.0,
            'stomping_interval': [0, 5],
            'stomping_removal': 1e-3,
            'sleep_recovery': 1,
            'measurement_mode': 'full_map',
            'exploration_mode': 'gradient_D80',
            'exploration_eta': 2,
            'exploration_map': 'vegetation_visits', #! SET THE BEHAVIORAL LOGIC
            'n_traces': 30,
            'decay_values': [0.001, 0.001, 0.005], #! decay for [exploration_eta, harvest_threshold, maximum_load]
            'exploration_N_recovery': 24,
            'print': False,
            'controller': {                
                'name':'P_repulsive',
                'Kp': 1*1e-2,
                'Kd': 0*1e-1,
                'Ki': 1*1e-3,
                'neighbourhood_size': 8,
                'river_barrier': 0.0,
                'max': 5.0,
                'accuracy': 1e-2,
                'dimension': 2,
                'map_repulsive': 'vegetation_quality', #! SET THE REPULSIVE MAP
                'beta_repulsive': 0.99,
            },
            'dynamics': {
                'name':'integrator',
                'mass':1.0,
                'friction':1.0
            }
        },
    'simulation':
        {
            'seed': 10,
            'timedelta': 1.0,
            'schedule_policy': 'sequential',
            'gui': True,
            'number_of_agents': 5,
            'print': True,
            'number_of_steps': 365*1,
            'downsampling': 7*24,
            'output_dir': 'outputs/fig/journal',
            'save_path': 'outputs/maps/environment_map_explore_grass.npy'
        },    
    }

# %%
from IPython.display import clear_output
fedeoli_beavers_scenario_GIF(beavers_running_config)
clear_output(wait=True)
# Out:
#   2%|▏         | 161/8760 [00:02<02:37, 54.47it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 from IPython.display import clear_output
# ----> 2 fedeoli_beavers_scenario_GIF(beavers_running_config)
#       3 clear_output(wait=True)
#
# File ~/Documents/Work/Projects/pushing_ws/earth_moving/earth_moving/scenarios/fedeoli_beavers_scenario_GIF.py:46, in fedeoli_beavers_scenario_GIF(config)
#      43         # Clear the figure to avoid overlapping plots
#      44         Backend._fig.clf()
# ---> 46     Backend.step()
#      47     clear_output(wait=True)
#      49 Backend.save_environment_map(save_path)
#
# File ~/Documents/Work/Projects/pushing_ws/earth_moving/earth_moving/ral/backend/beavers_visualizer_backend.py:157, in BeaversVisualizerBackend.step(self)
# ...
