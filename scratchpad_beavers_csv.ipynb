# %%
import sys
import os

# Method 1: Add project root to Python path
#project_root = 'Users\Wyss User\Desktop\BeaverBot\earth_moving'
#sys.path.append(project_root)



#print(f"Added to Python path: {project_root}")
print(f"Changed working directory to: {os.getcwd()}")
print("Ready to import earth_moving modules!")
# Out:
# Changed working directory to: c:\Users\Wyss User\Desktop\BeaverBot\earth_moving\earth_moving
# Ready to import earth_moving modules!

# %%
from earth_moving.scenarios.fedeoli_beavers_scenario import fedeoli_beavers_scenario

beavers_running_config = {
    'backend_type': 'beavers_visualizer',    
    'environment':
        {
          'name': 'beavers_environment',
          'map_mode': 'csv',
          'elevation_file_path': '/home/fedeoli/Documents/Work/Projects/pushing_ws/earth_moving/earth_moving/clutter/csv_analysis/output/elevation_with_vegetation.npy',  # Path to the CSV or NPY file
          'latitude_file_path': '/home/fedeoli/Documents/Work/Projects/pushing_ws/earth_moving/earth_moving/clutter/csv_analysis/output/X_coordinates.npy',
          'longitude_file_path': '/home/fedeoli/Documents/Work/Projects/pushing_ws/earth_moving/earth_moving/clutter/csv_analysis/output/Y_coordinates.npy',
          'vegetation_quality_range': [1, 10],
          'flow_info': {
              'direction': [-1, -1],     
              'strength': 1.0,         
              'streams_width': 10, # depth
              'river_growth_velocity': 0.001,
          },
          'print': False,
        },
    'robot':
        {
            'name': 'beavers_robot',
            'position': 'random_home',
            'home_base_position': [[130, 350]],
            'range_x': [-5, 5],               
            'range_y': [-5, 5],            
            'initial_load': 0,                   
            'maximum_load': 100,
            'initial_energy': 100,               
            'motion_consumption': 0,             
            'load_consumption': 0,               
            'harvest_consumption': 0,            
            'harvest_threshold': [0, 4],
            'vegetation_removal': 2.0,
            'sleep_recovery': 1,
            'measurement_mode': 'full_map',
            'exploration_mode': 'gradient_D40',
            'exploration_eta': 1.0,
            'exploration_map': 'vegetation_visits', #! SET THE BEHAVIORAL LOGIC
            'exploration_N_recovery': 40,
            'print': False,
            'controller': {                
                'name':'P_repulsive',
                'Kp': 1*1e-1,
                'Kd': 0*1e-1,
                'Ki': 1*1e-3,
                'map_repulsive': 'vegetation_visits',
                'neighbourhood_size': 80,
                'visits_reset': 0.9,
                'beta_repulsive': 0.5,
                'vegetation_barrier': [0.0, 10.0],
                'river_barrier': 0.0,
                'max': 40.0,
                'accuracy': 1e-2,
                'dimension': 2,
            },
            'dynamics': {
                'name':'integrator',
                'mass':1.0,
                'friction':1.0
            }
        },
    'simulation':
        {
            'seed': 10,
            'timedelta': 1.0,
            'schedule_policy': 'sequential',
            'gui': True,
            'number_of_agents': 10,
            'print': True,
            'number_of_steps': 365*2,
            'downsampling': 1*24,
        },    
    }
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from scenarios.fedeoli_beavers_scenario import fedeoli_beavers_scenario
#       3 beavers_running_config = {
#       4     'backend_type': 'beavers_visualizer',
#       5     'environment':
#    (...)
#      74         },
#      75     }
#
# File c:\Users\Wyss User\Desktop\BeaverBot\earth_moving\earth_moving\scenarios\fedeoli_beavers_scenario.py:1
# ----> 1 from earth_moving.ral.backend.base_backend import BaseBackend
#       2 from earth_moving.ral.environment.environment_beavers_backend import BeaversEnvironmentBackend
#       3 from IPython.display import clear_output
#
# ModuleNotFoundError: No module named 'earth_moving'

# %%
fedeoli_beavers_scenario(beavers_running_config)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 fedeoli_beavers_scenario(beavers_running_config)
#
# NameError: name 'fedeoli_beavers_scenario' is not defined

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 7E9A-7375
#
#  Directory of c:\Users\Wyss User\Desktop\BeaverBot\earth_moving\earth_moving\clutter
#
# 09/30/2025  12:18 PM    <DIR>          .
# 09/30/2025  12:18 PM    <DIR>          ..
# 09/30/2025  12:16 PM    <DIR>          .ipynb_checkpoints
# 09/30/2025  11:56 AM    <DIR>          csv_analysis
# 09/30/2025  11:56 AM            11,079 scratchpad_beavers.ipynb
# 09/30/2025  12:24 PM             6,776 scratchpad_beavers_csv.ipynb
# 09/30/2025  11:56 AM             5,134 scratchpad_beavers_GIF.ipynb
#                3 File(s)         22,989 bytes
#                4 Dir(s)  82,846,937,088 bytes free

# %%
..
