# %%
from earth_moving.scenarios.fedeoli_beavers_scenario import fedeoli_beavers_scenario

beavers_running_config = {
    'backend_type': 'beavers_visualizer',    
    'environment':
        {
          'name': 'beavers_environment',
          'map_mode': 'csv',
          'elevation_file_path': 'earth_moving/clutter/csv_analysis/output/elevation.npy',
        #   'elevation_file_path': 'outputs/maps/environment_map_explore_grass.npy',
          'latitude_file_path': 'earth_moving/clutter/csv_analysis/output/X_coordinates.npy',
          'longitude_file_path': 'earth_moving/clutter/csv_analysis/output/Y_coordinates.npy',
          'vegetation_quality_range': [0, 10],
          'grass_growth_rate': 1e-3,
          'grass_growth_interval': [0, 3],
          'visits_reset': 0.999,
          'flow_info': {
              'direction': [0, 0],
              'strength': 0.0,
              'streams_width': 10,  # depth
              'river_growth_velocity': 5e0,
          },
          'print': False,
        },
    'robot':
        {
            'name': 'beavers_robot',
            'position': 'random_home',
            'home_base_position': [[200,210]],
            'range_x': [-3, 3],
            'range_y': [-3, 3],            
            'initial_load': 0,                   
            'maximum_load': 20,
            'initial_energy': 100,               
            'motion_consumption': 0,             
            'load_consumption': 0,               
            'harvest_consumption': 0,            
            'harvest_threshold': [[-10,2]], 
            'vegetation_removal': 0.0,
            'stomping_interval': [0, 5],
            'stomping_removal': 1e-3,
            'sleep_recovery': 1,
            'measurement_mode': 'full_map',
            'exploration_mode': 'gradient_D100', #! HOW FAR CAN THE BEAVER SEE?
            'measure_step': 4,
            'exploration_eta': 1e2,
            'exploration_gaussian_locality_sigma': 1e3,
            'exploration_map': 'vegetation_quality', #! SET THE BEHAVIORAL LOGIC
            'n_traces': 30,
            'decay_values': [0.000, 0.000, 0.000], #! decay for [exploration_eta, harvest_threshold, maximum_load]
            'exploration_N_recovery': 10,
            'print': False,
            'controller': {                
                'name':'P_repulsive',
                'Kp': 1*1e-2,
                'Kd': 0*1e-1,
                'Ki': 1*5e-3,
                'neighbourhood_size': 2,                
                'max': 10.0,
                'accuracy': 1e-2,
                'dimension': 2,
                'map_repulsive': 'vegetation_quality', #! SET THE REPULSIVE MAP
                'beta_repulsive': 0.75,
            },
            'dynamics': {
                'name':'integrator',
                'mass':1.0,
                'friction':1.0
            }
        },
    'simulation':
        {
            'seed': 10,
            'timedelta': 1.0,
            'schedule_policy': 'sequential',
            'gui': True,
            'number_of_agents': 5,
            'print': True,
            'number_of_steps': 365*1,
            'downsampling': 7*24,
            'save_path': 'outputs/maps/environment_map_test.npy'
        },    
    }

# %%
fedeoli_beavers_scenario(beavers_running_config)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 fedeoli_beavers_scenario(beavers_running_config)
#
# File ~/Documents/Work/Projects/pushing_ws/earth_moving/earth_moving/scenarios/fedeoli_beavers_scenario.py:26, in fedeoli_beavers_scenario(config)
#      23         Backend.plot_environment_with_heatmap(plot_agents=True)
#      24         # Backend.plot_simulation_recap()
# ---> 26     Backend.step()
#      27     clear_output(wait=True)
#      29 # final plots
#
# File ~/Documents/Work/Projects/pushing_ws/earth_moving/earth_moving/ral/backend/beavers_visualizer_backend.py:157, in BeaversVisualizerBackend.step(self)
#     155     sorted_agents = sorted(self._schedule.agents, key=lambda agent: agent.unique_id)
#     156     for agent in sorted_agents:
# --> 157         agent.step()
#     158 elif self._schedule_policy == 'random':
#     159     self._schedule.step()
#
# File ~/Documents/Work/Projects/pushing_ws/earth_moving/earth_moving/ral/backend/beavers_visualizer_backend.py:841, in BeaversVisualizerAgent.step(self)
#     834 misc = {
#     835     'direction': self.model._environment._flow_direction,
#     836     'strength': self.model._environment._flow_strength,
#     837     'visits': self.model._environment._map_visits
#     838 }
#     840 # step the agent
# --> 841 self.step_beaver(dt,
#     842                  time_of_day,
#     843                  map_quality,
#     844                  limits,
#     845                  misc)
#     847 #! here we update the environment with the agent's actions
#     848 #! note that we only update the current position because it's the only the beaver can actually change
#     849 self.model._environment._map_original[self._position[0], self._position[1]] = self._map_quality_measure_position
#
# File ~/Documents/Work/Projects/pushing_ws/earth_moving/earth_moving/ral/robot/robot_beavers_backend.py:545, in BeaversRobotBackend.step_beaver(self, dt, time_of_day, map_quality, limits, misc)
#     543 self.decide_task(time_of_day, limits, misc)
#     544 # do the task (TASK IMPLEMENTATION)
# --> 545 self.do_task(time_of_day, limits, misc)
#     546 # update energy
#     547 self.update_energy()
#
# File ~/Documents/Work/Projects/pushing_ws/earth_moving/earth_moving/ral/robot/robot_beavers_backend.py:760, in BeaversRobotBackend.do_task(self, time_of_day, limits, misc)
#     757 if self._current_task == 'explore':
#     758     # first time you get the neighbors and set the status to INPROGRESS
#     759     if self._status_task is 'STARTING':
# --> 760         self.get_neighbourhood()
#     761         self._status_task = 'INPROGRESS'
#     762     self.explore(time_of_day, limits, misc)
#
# File ~/Documents/Work/Projects/pushing_ws/earth_moving/earth_moving/ral/robot/robot_beavers_backend.py:1394, in BeaversRobotBackend.get_neighbourhood(self)
#    1391 y_coords, x_coords = self.np.ogrid[:local_map.shape[0], :local_map.shape[1]]
#    1393 # Calculate distance from current position to each cell
# -> 1394 distance_from_position = self.np.sqrt((x_coords - position[1])**2 + (y_coords - position[0])**2)
#    1396 # Create Gaussian weight matrix (closer points have higher weight)
#    1397 # Sigma determines the "locality preference" - smaller values = stronger preference for nearby points
#    1398 distance_weight = self.np.exp(-(distance_from_position**2) / (2 * self._exploration_gaussian_locality_sigma**2))
#
# KeyboardInterrupt:
